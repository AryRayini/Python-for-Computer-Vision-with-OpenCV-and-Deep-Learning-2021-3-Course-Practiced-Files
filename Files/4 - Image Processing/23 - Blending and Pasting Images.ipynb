# %%
import cv2

# %%
# Getting First Image
img1 = cv2.imread('DATA/dog_backpack.jpg')
# Change Color Space To RGB
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

################################################
################################################

# Getting Second Image
img2 = cv2.imread('DATA/watermark_no_copy.png')
# Change Color Space to RGB
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
# Imports For Showing Them
import matplotlib.pylab as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
## Blending images to the same size ##

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1 , alpha = 0.8, src2 = img2, beta = 0.2,gamma = 0 )

# %%
plt.imshow(blended)

# %%
## overlay an small image on top of an larger image ( no blending ) ##
# Numpy reassignment ( taking value of large image and assign them to smaller image ) #

# %%
### Reloading images again ###

# Getting First Image
img1 = cv2.imread('DATA/dog_backpack.jpg')
# Change Color Space To RGB
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

################################################
################################################

# Getting Second Image
img2 = cv2.imread('DATA/watermark_no_copy.png')
# Change Color Space to RGB
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0
y_offset = 0

# %%
# x_offset + the legth of x in small image
x_end = x_offset + small_img.shape[1]
# y_offset + the legth of y in small image
y_end = y_offset + small_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
large_img[y_offset:y_end , x_offset:x_end ] = small_img

# %%
plt.imshow(large_img)

# %%
# Blend together images of different sizes
